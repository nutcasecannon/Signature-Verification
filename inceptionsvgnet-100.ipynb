# %%
import os
import cv2
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split

# %%
# Define paths for three datasets
DATASET_PATHS = [
    r'/kaggle/input/cedarbhsig-260/Reconstructed_CEDAR/Reconstructed_CEDAR',
    r'/kaggle/input/cedarbhsig-260/Reconstructed_BHSig100-20250403T193101Z-001/Reconstructed_BHSig100'
    r'/kaggle/input/cedarbhsig-260/Reconstructed_BHSig160-20250403T183033Z-001/Reconstructed_BHSig160'
]

# Preprocessing functions remain unchanged
def preprocess_signature(image_path):
    """Generate two processed images: filtered and grayscale."""
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    if image is None:
        return None, None

    image = cv2.resize(image, (256, 128))
    filtered = cv2.dilate(image, np.ones((3,3), np.uint8), iterations=1)
    filtered = cv2.GaussianBlur(filtered, (5,5), 0)
    _, filtered = cv2.threshold(filtered, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
    return filtered, image.copy()

# Modified dataset loader for multiple datasets
def load_multiple_datasets(dataset_paths):
    all_X_train, all_y_train = [], []
    test_sets = []
    i=0
    for path in dataset_paths:
        i=i+1
        images, labels = [], []
        for user_folder in os.listdir(path):
            user_path = os.path.join(path, user_folder)
            if os.path.isdir(user_path):
                for img_name in os.listdir(user_path):
                    img_path = os.path.join(user_path, img_name)
                    filtered, grayscale = preprocess_signature(img_path)
                    if filtered is not None:
                        stacked = np.stack([filtered, grayscale], axis=-1)
                        images.append(stacked)
                        if (i==1):
                          labels.append(0 if "original" in img_name else 1)
                        else :
                          labels.append(0 if "G" in img_name else 1)

        X = np.array(images, dtype=np.float32) / 255.0
        y = np.array(labels)

        # Split dataset into 70-30
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
        all_X_train.append(X_train)
        all_y_train.append(y_train)
        test_sets.append((X_test, y_test))

    # Combine training data from all datasets
    X_train_combined = np.concatenate(all_X_train)
    y_train_combined = np.concatenate(all_y_train)

    # Shuffle combined training data
    indices = np.random.permutation(len(X_train_combined))
    return X_train_combined[indices], y_train_combined[indices], test_sets

# Load and split all datasets
X_train, y_train, test_sets = load_multiple_datasets(DATASET_PATHS)

# %%
def build_inception_svgnet():
    input_layer = keras.Input(shape=(128, 256, 2))
    
    def inception_module(x, filters):
    # Ensure filters are at least 1
        conv1 = layers.Conv2D(filters, (16,16), padding='same', activation='relu')(x)
        conv2 = layers.Conv2D(filters, (8,8), padding='same', activation='relu')(x)
        conv3 = layers.Conv2D(filters, (4,4), padding='same', activation='relu')(x)
        conv4 = layers.Conv2D(filters, (2,2), padding='same', activation='relu')(x)
        return layers.Concatenate()([conv1, conv2, conv3, conv4])


    x = inception_module(input_layer, 16)
    x = layers.Dropout(0.5)(x)
    x = layers.AveragePooling2D(pool_size=(2,2))(x)
    x = inception_module(x, 24)
    x = layers.Dropout(0.5)(x)
    x = layers.AveragePooling2D(pool_size=(2,2))(x)
    x = inception_module(x, 32)
    x = layers.Dropout(0.5)(x)
    x = layers.AveragePooling2D(pool_size=(2,2))(x)

    x = layers.Conv2D(64, (4,4), activation='relu')(x)
    x = layers.Dropout(0.5)(x)
    x = layers.AveragePooling2D(pool_size=(2,2))(x)
    x = layers.Flatten()(x)
    x = layers.Dense(256, activation='relu')(x)
    x = layers.Dropout(0.5)(x)
    x = layers.Dense(256, activation='relu')(x)
    x = layers.Dropout(0.5)(x)
    output_layer = layers.Dense(2, activation='softmax')(x)

    model = keras.Model(input_layer, output_layer)
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# Initialize and train model
model = build_inception_svgnet()
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 128, 256, 2)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d (Conv2D)           │ (None, 128, 256, 16)   │          8,208 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1 (Conv2D)         │ (None, 128, 256, 16)   │          2,064 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_2 (Conv2D)         │ (None, 128, 256, 16)   │            528 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_3 (Conv2D)         │ (None, 128, 256, 16)   │            144 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate (Concatenate) │ (None, 128, 256, 64)   │              0 │ conv2d[0][0],          │
# │                           │                        │                │ conv2d_1[0][0],        │
# │                           │                        │                │ conv2d_2[0][0],        │
# │                           │                        │                │ conv2d_3[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout (Dropout)         │ (None, 128, 256, 64)   │              0 │ concatenate[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ average_pooling2d         │ (None, 64, 128, 64)    │              0 │ dropout[0][0]          │
# │ (AveragePooling2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_4 (Conv2D)         │ (None, 64, 128, 24)    │        393,240 │ average_pooling2d[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_5 (Conv2D)         │ (None, 64, 128, 24)    │         98,328 │ average_pooling2d[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_6 (Conv2D)         │ (None, 64, 128, 24)    │         24,600 │ average_pooling2d[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_7 (Conv2D)         │ (None, 64, 128, 24)    │          6,168 │ average_pooling2d[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_1             │ (None, 64, 128, 96)    │              0 │ conv2d_4[0][0],        │
# │ (Concatenate)             │                        │                │ conv2d_5[0][0],        │
# │                           │                        │                │ conv2d_6[0][0],        │
# │                           │                        │                │ conv2d_7[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_1 (Dropout)       │ (None, 64, 128, 96)    │              0 │ concatenate_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ average_pooling2d_1       │ (None, 32, 64, 96)     │              0 │ dropout_1[0][0]        │
# │ (AveragePooling2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_8 (Conv2D)         │ (None, 32, 64, 32)     │        786,464 │ average_pooling2d_1[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_9 (Conv2D)         │ (None, 32, 64, 32)     │        196,640 │ average_pooling2d_1[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_10 (Conv2D)        │ (None, 32, 64, 32)     │         49,184 │ average_pooling2d_1[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_11 (Conv2D)        │ (None, 32, 64, 32)     │         12,320 │ average_pooling2d_1[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_2             │ (None, 32, 64, 128)    │              0 │ conv2d_8[0][0],        │
# │ (Concatenate)             │                        │                │ conv2d_9[0][0],        │
# │                           │                        │                │ conv2d_10[0][0],       │
# │                           │                        │                │ conv2d_11[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_2 (Dropout)       │ (None, 32, 64, 128)    │              0 │ concatenate_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ average_pooling2d_2       │ (None, 16, 32, 128)    │              0 │ dropout_2[0][0]        │
# │ (AveragePooling2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_12 (Conv2D)        │ (None, 13, 29, 64)     │        131,136 │ average_pooling2d_2[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_3 (Dropout)       │ (None, 13, 29, 64)     │              0 │ conv2d_12[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ average_pooling2d_3       │ (None, 6, 14, 64)      │              0 │ dropout_3[0][0]        │
# │ (AveragePooling2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten (Flatten)         │ (None, 5376)           │              0 │ average_pooling2d_3[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 256)            │      1,376,512 │ flatten[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_4 (Dropout)       │ (None, 256)            │              0 │ dense[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_1 (Dense)           │ (None, 256)            │         65,792 │ dropout_4[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_5 (Dropout)       │ (None, 256)            │              0 │ dense_1[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_2 (Dense)           │ (None, 2)              │            514 │ dropout_5[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 3,151,842 (12.02 MB)
#  Trainable params: 3,151,842 (12.02 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(X_train, y_train, validation_split=0.2, epochs=40, batch_size=160)

# Evaluate on each test set individually
for i, (X_test, y_test) in enumerate(test_sets, 1):
    loss, accuracy = model.evaluate(X_test, y_test, verbose=0)
    print(f'Dataset {i} Test Accuracy: {accuracy*100:.2f}%')
# Out:
# Epoch 1/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 348s 4s/step - accuracy: 0.5262 - loss: 0.9929 - val_accuracy: 0.5420 - val_loss: 0.6888
# Epoch 2/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 97s 2s/step - accuracy: 0.5449 - loss: 0.6893 - val_accuracy: 0.5492 - val_loss: 0.6846
# Epoch 3/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 97s 2s/step - accuracy: 0.5919 - loss: 0.6630 - val_accuracy: 0.6755 - val_loss: 0.6149
# Epoch 4/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 97s 2s/step - accuracy: 0.6722 - loss: 0.6044 - val_accuracy: 0.7307 - val_loss: 0.5586
# Epoch 5/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 97s 2s/step - accuracy: 0.7282 - loss: 0.5562 - val_accuracy: 0.7350 - val_loss: 0.5312
# Epoch 6/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 97s 2s/step - accuracy: 0.7539 - loss: 0.5142 - val_accuracy: 0.7658 - val_loss: 0.4767
# Epoch 7/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 96s 2s/step - accuracy: 0.7840 - loss: 0.4681 - val_accuracy: 0.7804 - val_loss: 0.4587
# Epoch 8/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 96s 2s/step - accuracy: 0.7967 - loss: 0.4441 - val_accuracy: 0.8031 - val_loss: 0.4251
# Epoch 9/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 96s 2s/step - accuracy: 0.8075 - loss: 0.4206 - val_accuracy: 0.7808 - val_loss: 0.4822
# Epoch 10/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 96s 2s/step - accuracy: 0.8374 - loss: 0.3747 - val_accuracy: 0.8433 - val_loss: 0.3360
# Epoch 11/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 96s 2s/step - accuracy: 0.8316 - loss: 0.3685 - val_accuracy: 0.7748 - val_loss: 0.8199
# Epoch 12/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 96s 2s/step - accuracy: 0.8468 - loss: 0.3505 - val_accuracy: 0.8592 - val_loss: 0.3191
# Epoch 13/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 96s 2s/step - accuracy: 0.8749 - loss: 0.2977 - val_accuracy: 0.8780 - val_loss: 0.2865
# Epoch 14/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 96s 2s/step - accuracy: 0.8788 - loss: 0.2854 - val_accuracy: 0.8502 - val_loss: 0.3704
# Epoch 15/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 96s 2s/step - accuracy: 0.8691 - loss: 0.3314 - val_accuracy: 0.8776 - val_loss: 0.2986
# Epoch 16/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 96s 2s/step - accuracy: 0.8698 - loss: 0.2994 - val_accuracy: 0.8707 - val_loss: 0.2958
# Epoch 17/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 96s 2s/step - accuracy: 0.8896 - loss: 0.2658 - val_accuracy: 0.8887 - val_loss: 0.2647
# Epoch 18/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 96s 2s/step - accuracy: 0.9081 - loss: 0.2158 - val_accuracy: 0.9157 - val_loss: 0.2065
# Epoch 19/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 96s 2s/step - accuracy: 0.9065 - loss: 0.2260 - val_accuracy: 0.8977 - val_loss: 0.2441
# Epoch 20/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 96s 2s/step - accuracy: 0.9248 - loss: 0.1900 - val_accuracy: 0.8977 - val_loss: 0.2373
# Epoch 21/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 96s 2s/step - accuracy: 0.9287 - loss: 0.1870 - val_accuracy: 0.9178 - val_loss: 0.2020
# Epoch 22/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 96s 2s/step - accuracy: 0.9376 - loss: 0.1550 - val_accuracy: 0.9011 - val_loss: 0.3348
# Epoch 23/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 96s 2s/step - accuracy: 0.9209 - loss: 0.2265 - val_accuracy: 0.9358 - val_loss: 0.1755
# Epoch 24/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 96s 2s/step - accuracy: 0.9238 - loss: 0.1771 - val_accuracy: 0.9358 - val_loss: 0.1758
# Epoch 25/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 96s 2s/step - accuracy: 0.9339 - loss: 0.1617 - val_accuracy: 0.9461 - val_loss: 0.1426
# Epoch 26/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 96s 2s/step - accuracy: 0.9510 - loss: 0.1324 - val_accuracy: 0.9401 - val_loss: 0.1480
# Epoch 27/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 96s 2s/step - accuracy: 0.9554 - loss: 0.1215 - val_accuracy: 0.9491 - val_loss: 0.1382
# Epoch 28/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 96s 2s/step - accuracy: 0.9555 - loss: 0.1199 - val_accuracy: 0.9469 - val_loss: 0.1456
# Epoch 29/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 96s 2s/step - accuracy: 0.9562 - loss: 0.1183 - val_accuracy: 0.9491 - val_loss: 0.1416
# Epoch 30/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 96s 2s/step - accuracy: 0.9552 - loss: 0.1140 - val_accuracy: 0.9533 - val_loss: 0.1326
# Epoch 31/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 96s 2s/step - accuracy: 0.9665 - loss: 0.0933 - val_accuracy: 0.9521 - val_loss: 0.1346
# Epoch 32/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 96s 2s/step - accuracy: 0.9609 - loss: 0.1025 - val_accuracy: 0.9546 - val_loss: 0.1266
# Epoch 33/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 96s 2s/step - accuracy: 0.9676 - loss: 0.0872 - val_accuracy: 0.9653 - val_loss: 0.1111
# Epoch 34/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 96s 2s/step - accuracy: 0.9750 - loss: 0.0769 - val_accuracy: 0.9606 - val_loss: 0.1255
# Epoch 35/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 96s 2s/step - accuracy: 0.9687 - loss: 0.0808 - val_accuracy: 0.9602 - val_loss: 0.1118
# Epoch 36/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 96s 2s/step - accuracy: 0.9772 - loss: 0.0633 - val_accuracy: 0.9589 - val_loss: 0.1303
# Epoch 37/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 96s 2s/step - accuracy: 0.9699 - loss: 0.0740 - val_accuracy: 0.9653 - val_loss: 0.1116
# Epoch 38/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 96s 2s/step - accuracy: 0.9715 - loss: 0.0712 - val_accuracy: 0.9683 - val_loss: 0.1024
# Epoch 39/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 96s 2s/step - accuracy: 0.9724 - loss: 0.0738 - val_accuracy: 0.9619 - val_loss: 0.1138
# Epoch 40/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 96s 2s/step - accuracy: 0.9776 - loss: 0.0565 - val_accuracy: 0.9679 - val_loss: 0.1184
# Dataset 1 Test Accuracy: 100.00%
# Dataset 2 Test Accuracy: 95.93%
# Dataset 3 Test Accuracy: 94.83%
